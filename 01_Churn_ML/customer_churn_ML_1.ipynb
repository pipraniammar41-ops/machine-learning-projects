# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('customer_churn_ml_practice.csv')

# %%
df.head()
# Out:
#   customer_id   age  gender signup_date   contract_type internet_service  \
# 0  CUST100877  35.0  Female  2025-02-26  Month-to-month      No internet
# 1  CUST104885  34.0    Male  2025-08-20        One year              DSL
# 2  CUST102484  37.0  Female  2021-08-25        One year              DSL
# 3  CUST102288  50.0    Male  2022-10-09        One year      Fiber optic
# 4  CUST100811  31.0    Male  2025-09-28  Month-to-month              DSL
#
#      payment_method  tenure_months  monthly_charges  total_charges  \
# 0       Credit card             10            67.42         717.36
# 1     Bank transfer              4            44.08         166.14
# 2     Bank transfer             52            32.90        1772.94
# 3  Electronic check             39              NaN        2136.76
# 4      Mailed check              3            58.23         193.64
#
#    num_services  support_tickets  late_payments  satisfaction_score  \
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'signup_date', 'contract_type',
#        'internet_service', 'payment_method', 'tenure_months',
#        'monthly_charges', 'total_charges', 'num_services', 'support_tickets',
#        'late_payments', 'satisfaction_score', 'last_login_days', 'city',
#        'churn'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5025 entries, 0 to 5024
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         5025 non-null   str
#  1   age                 4965 non-null   float64
#  2   gender              4974 non-null   str
#  3   signup_date         5025 non-null   str
#  4   contract_type       5025 non-null   str
#  5   internet_service    5025 non-null   str
#  6   payment_method      4935 non-null   str
#  7   tenure_months       5025 non-null   int64
#  8   monthly_charges     4965 non-null   float64
#  9   total_charges       5020 non-null   float64
#  10  num_services        5025 non-null   int64
#  11  support_tickets     5025 non-null   int64
#  12  late_payments       5025 non-null   int64
#  13  satisfaction_score  4923 non-null   float64
#  14  last_login_days     4950 non-null   float64
#  15  city                4975 non-null   str
# ...

# %%
df.describe()
# Out:
#                age  tenure_months  monthly_charges  total_charges  \
# count  4965.000000    5025.000000      4965.000000    5020.000000
# mean     38.090232      30.250547        60.934775    1805.918510
# std      11.713729      17.005874        25.985621    1205.901537
# min       9.000000       1.000000        18.000000    -500.000000
# 25%      30.000000      15.000000        46.870000     816.412500
# 50%      38.000000      30.000000        59.710000    1635.190000
# 75%      46.000000      45.000000        72.510000    2567.990000
# max     120.000000      60.000000       600.000000    7005.470000
#
#        num_services  support_tickets  late_payments  satisfaction_score  \
# count   5025.000000      5025.000000    5025.000000         4923.000000
# mean       3.999403         1.706866       1.208358            6.789965
# std        1.683507         1.296217       1.095995            1.428851
# min        1.000000         0.000000       0.000000            2.000000
# ...

# %%
df.isnull().sum()
# Out:
# customer_id             0
# age                    60
# gender                 51
# signup_date             0
# contract_type           0
# internet_service        0
# payment_method         90
# tenure_months           0
# monthly_charges        60
# total_charges           5
# num_services            0
# support_tickets         0
# late_payments           0
# satisfaction_score    102
# last_login_days        75
# city                   50
# churn                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(25)

# %%
df['gender'].value_counts()
# Out:
# gender
# Male        2478
# Female      2416
#  female       40
# MALE          40
# Name: count, dtype: int64

# %%
df['contract_type'].value_counts()
# Out:
# contract_type
# Month-to-month    2713
# One year          1450
# Two year           862
# Name: count, dtype: int64

# %%
df['internet_service'].value_counts()
# Out:
# internet_service
# Fiber optic    2321
# DSL            1938
# No internet     766
# Name: count, dtype: int64

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# Electronic check      1747
# Credit card           1424
# Bank transfer         1117
# Mailed check           607
#  electronic check       40
# Name: count, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# Chennai      904
# Mumbai       834
# Hyderabad    831
# Pune         807
# Bengaluru    807
# Delhi        792
# Name: count, dtype: int64

# %%
df['churn'].value_counts()
# Out:
# churn
# No     4421
# Yes     604
# Name: count, dtype: int64

# %%
sns.histplot(data=df,x='age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df, x='monthly_charges')
# Out:
# <Axes: xlabel='monthly_charges', ylabel='Count'>

# %%
sns.histplot(data=df, x='total_charges')
# Out:
# <Axes: xlabel='total_charges', ylabel='Count'>

# %%
sns.histplot(data=df, x='satisfaction_score')
# Out:
# <Axes: xlabel='satisfaction_score', ylabel='Count'>

# %%
sns.boxplot(data=df, x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(data=df, x='monthly_charges')
# Out:
# <Axes: xlabel='monthly_charges'>

# %%
sns.boxplot(data=df, x='total_charges')
# Out:
# <Axes: xlabel='total_charges'>

# %%
sns.boxplot(data=df, x='satisfaction_score')
# Out:
# <Axes: xlabel='satisfaction_score'>

# %%
Q1 = df['age'].quantile(0.25)
Q1
# Out:
# np.float64(30.0)

# %%
Q3 = df['age'].quantile(0.75)
Q3
# Out:
# np.float64(46.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# np.float64(16.0)

# %%
lower_bound = Q1 - 1.5 * IQR
lower_bound
# Out:
# np.float64(6.0)

# %%
upper_bound = Q3 + 1.5 * IQR
upper_bound
# Out:
# np.float64(70.0)

# %%
df[df['age'] > upper_bound]
# Out:
#      customer_id    age    gender signup_date   contract_type  \
# 5     CUST100248   73.0      Male  2023-10-10  Month-to-month
# 172   CUST101769   72.0    Female  2021-08-04        One year
# 212   CUST102042  120.0    Female  2022-09-28  Month-to-month
# 397   CUST102103   96.0    Female  2024-12-19  Month-to-month
# 420   CUST101616   73.0   female   2025-01-09        One year
# 862   CUST103574   96.0      Male  2021-02-21        One year
# 978   CUST100139   73.0    Female  2025-09-04        One year
# 984   CUST101338   71.0    Female  2021-01-12  Month-to-month
# 1331  CUST100622  120.0    Female  2024-02-02  Month-to-month
# 1554  CUST104222   75.0      Male  2023-12-24        One year
# 1895  CUST102053   72.0      Male  2021-03-28        Two year
# 1920  CUST104761   72.0    Female  2021-05-25        Two year
# 2081  CUST103732   72.0    Female  2023-06-25        Two year
# 2414  CUST103424   72.0      Male  2021-06-09        One year
# ...

# %%
df[df['age'] < lower_bound]
# Out:
# Empty DataFrame
# Columns: [customer_id, age, gender, signup_date, contract_type, internet_service, payment_method, tenure_months, monthly_charges, total_charges, num_services, support_tickets, late_payments, satisfaction_score, last_login_days, city, churn]
# Index: []

# %%
df[df['age'] > upper_bound].shape[0]
# Out:
# 27

# %%
df[df['age'] == 120]
# Out:
#      customer_id    age  gender signup_date   contract_type internet_service  \
# 212   CUST102042  120.0  Female  2022-09-28  Month-to-month      Fiber optic
# 1331  CUST100622  120.0  Female  2024-02-02  Month-to-month      Fiber optic
# 4414  CUST101823  120.0    Male  2025-11-27        One year      Fiber optic
#
#         payment_method  tenure_months  monthly_charges  total_charges  \
# 212   Electronic check             39            75.10        2706.40
# 1331     Bank transfer             23            86.07        2270.61
# 4414     Bank transfer              1            76.03          66.76
#
#       num_services  support_tickets  late_payments  satisfaction_score  \
# 212              6                2              4                 8.0
# 1331             5                3              1                 5.0
# 4414             5                1              2                 6.0
#
#       last_login_days       city churn
# 212              18.0        NaN    No
# ...

# %%
df.loc[df['age'] > upper_bound,'age'].value_counts().sort_index()
# Out:
# age
# 71.0     4
# 72.0     8
# 73.0     3
# 74.0     2
# 75.0     5
# 96.0     2
# 120.0    3
# Name: count, dtype: int64

# %%
df['age'].describe()
# Out:
# count    4965.000000
# mean       38.090232
# std        11.713729
# min         9.000000
# 25%        30.000000
# 50%        38.000000
# 75%        46.000000
# max       120.000000
# Name: age, dtype: float64

# %%
df[df['age'] == 120][['customer_id','age','signup_date']]
# Out:
#      customer_id    age signup_date
# 212   CUST102042  120.0  2022-09-28
# 1331  CUST100622  120.0  2024-02-02
# 4414  CUST101823  120.0  2025-11-27

# %%
df[df['age'] == 96] [['customer_id','age','signup_date']]
# Out:
#     customer_id   age signup_date
# 397  CUST102103  96.0  2024-12-19
# 862  CUST103574  96.0  2021-02-21

# %%
df[df['age'].isin([96, 120])][
    ['customer_id', 'age', 'signup_date', 'tenure_months',
     'monthly_charges', 'total_charges', 'num_services',
     'support_tickets', 'late_payments', 'satisfaction_score',
     'last_login_days', 'churn']
]
# Out:
#      customer_id    age signup_date  tenure_months  monthly_charges  \
# 212   CUST102042  120.0  2022-09-28             39            75.10
# 397   CUST102103   96.0  2024-12-19             12            61.71
# 862   CUST103574   96.0  2021-02-21             58            63.92
# 1331  CUST100622  120.0  2024-02-02             23            86.07
# 4414  CUST101823  120.0  2025-11-27              1            76.03
#
#       total_charges  num_services  support_tickets  late_payments  \
# 212         2706.40             6                2              4
# 397          715.03             2                1              2
# 862         4093.86             4                2              2
# 1331        2270.61             5                3              1
# 4414          66.76             5                1              2
#
#       satisfaction_score  last_login_days churn
# 212                  8.0             18.0    No
# 397                  6.0              8.0    No
# ...

# %%
df = df.drop(index=4414)

# %%
df[df['age'] == 120]
# Out:
#      customer_id    age  gender signup_date   contract_type internet_service  \
# 212   CUST102042  120.0  Female  2022-09-28  Month-to-month      Fiber optic
# 1331  CUST100622  120.0  Female  2024-02-02  Month-to-month      Fiber optic
#
#         payment_method  tenure_months  monthly_charges  total_charges  \
# 212   Electronic check             39            75.10        2706.40
# 1331     Bank transfer             23            86.07        2270.61
#
#       num_services  support_tickets  late_payments  satisfaction_score  \
# 212              6                2              4                 8.0
# 1331             5                3              1                 5.0
#
#       last_login_days     city churn
# 212              18.0      NaN    No
# 1331             24.0  Chennai    No

# %%
df.shape
# Out:
# (5024, 17)

# %%
Q1_monthly = df['monthly_charges'].quantile(0.25)

# %%
Q3_monthly = df['monthly_charges'].quantile(0.75)
Q1_monthly, Q3_monthly
# Out:
# (np.float64(46.87), np.float64(72.48))

# %%
IQR_monthly = Q3_monthly - Q1_monthly
IQR_monthly
# Out:
# np.float64(25.610000000000007)

# %%
lower_bound_monthly = Q1_monthly - 1.5 * IQR_monthly
upper_bound_monthly = Q3_monthly + 1.5 * IQR_monthly

lower_bound_monthly,upper_bound_monthly
# Out:
# (np.float64(8.454999999999991), np.float64(110.89500000000001))

# %%
df[df['monthly_charges'] > upper_bound_monthly].shape[0]
# Out:
# 25

# %%
df[df['monthly_charges'] > upper_bound_monthly][
    ['customer_id', 'monthly_charges', 'tenure_months',
     'total_charges', 'num_services', 'internet_service',
     'contract_type']
]
# Out:
#      customer_id  monthly_charges  tenure_months  total_charges  num_services  \
# 686   CUST100621           121.24             23        2393.14             8
# 695   CUST100787           116.26              6         674.44             8
# 785   CUST102378           111.48              3         304.12             8
# 1147  CUST104542           600.00             42        1602.44             3
# 1335  CUST102942           450.00             41        1692.87             3
# 1507  CUST101426           450.00             24        2555.78             8
# 1756  CUST100442           119.93             15        1967.73             8
# 1844  CUST104684           114.28              9        1055.29             8
# 1907  CUST102892           111.33             18        2055.11             8
# 2041  CUST101611           250.00             27        1650.84             5
# 2242  CUST101091           116.92             43        4614.43             8
# ...

# %%
df[df['monthly_charges'] >= 250][
    ['customer_id',
     'monthly_charges',
     'tenure_months',
     'total_charges',
     'num_services',
     'internet_service',
     'contract_type']
]
# Out:
#      customer_id  monthly_charges  tenure_months  total_charges  num_services  \
# 1147  CUST104542            600.0             42        1602.44             3
# 1335  CUST102942            450.0             41        1692.87             3
# 1507  CUST101426            450.0             24        2555.78             8
# 2041  CUST101611            250.0             27        1650.84             5
# 2247  CUST104120            250.0             54        2598.64             5
# 2824  CUST101735            300.0             45        2928.10             4
# 3364  CUST103467            250.0             46        2633.39             5
# 3522  CUST104734            600.0              9         515.86             4
# 3918  CUST103961            600.0             35        2089.37             3
# 3981  CUST100914            450.0             57        6030.34             6
# 4025  CUST102007            450.0              4         237.22             6
# ...

# %%
df[df['monthly_charges'] >= 250].index
# Out:
# Index([1147, 1335, 1507, 2041, 2247, 2824, 3364, 3522, 3918, 3981, 4025, 4252], dtype='int64')

# %%
df = df.drop(df[df['monthly_charges'] >= 250].index)

# %%
df.shape
# Out:
# (5012, 17)

# %%
df['monthly_charges'].max()
# Out:
# np.float64(121.24)

# %%
df[df['monthly_charges'] >= 250]
# Out:
# Empty DataFrame
# Columns: [customer_id, age, gender, signup_date, contract_type, internet_service, payment_method, tenure_months, monthly_charges, total_charges, num_services, support_tickets, late_payments, satisfaction_score, last_login_days, city, churn]
# Index: []

# %%
sns.histplot(data=df,x='total_charges')
# Out:
# <Axes: xlabel='total_charges', ylabel='Count'>

# %%
sns.boxplot(data=df,x='total_charges')
# Out:
# <Axes: xlabel='total_charges'>

# %%
Q1_charges= df['total_charges'].quantile(0.25)

# %%
Q1_charges
# Out:
# np.float64(816.385)

# %%
Q3_charges= df['total_charges'].quantile(0.75)

# %%
Q3_charges
# Out:
# np.float64(2566.3199999999997)

# %%
IQR_charges = Q3_charges - Q1_charges

# %%
IQR_charges
# Out:
# np.float64(1749.9349999999997)

# %%
lower_bound_charges= Q1_charges - 1.5 * IQR_charges
upper_bound_charges= Q3_charges + 1.5 * IQR_charges
lower_bound_charges,upper_bound_charges
# Out:
# (np.float64(-1808.5174999999997), np.float64(5191.2225))

# %%
df[df['total_charges'] >=upper_bound_charges].shape
# Out:
# (41, 17)

# %%
df[df['total_charges'] >=upper_bound_charges].shape
# Out:
# (41, 17)

# %%
df[df['customer_id'].duplicated()]
# Out:
#      customer_id   age  gender signup_date   contract_type internet_service  \
# 539   CUST100642  63.0  Female  2021-01-05  Month-to-month      Fiber optic
# 577   CUST102413  21.0    Male  2021-03-21        Two year              DSL
# 682   CUST101501  31.0    Male  2021-09-22  Month-to-month      No internet
# 718   CUST100926  36.0    Male  2021-11-09  Month-to-month              DSL
# 827   CUST101600  37.0    Male  2025-03-09  Month-to-month      Fiber optic
# 1019  CUST103543  43.0    Male  2023-12-14  Month-to-month      Fiber optic
# 1078  CUST100589  57.0  Female  2025-10-05        One year      Fiber optic
# 1539  CUST103049  55.0  Female  2021-11-23        One year              DSL
# 1738  CUST101744  46.0    Male  2023-08-18        One year      No internet
# 1915  CUST102653  28.0  Female  2022-04-06        One year              DSL
# 1940  CUST100794  18.0  Female  2022-04-03  Month-to-month              DSL
# ...

# %%
df['customer_id'].duplicated().sum()
# Out:
# np.int64(25)

# %%
df[df['customer_id'] == 'CUST100705'][
    ['customer_id',
     'monthly_charges',
     'tenure_months',
     'total_charges',
     'num_services',
     'internet_service',
     'contract_type']
]
# Out:
#      customer_id  monthly_charges  tenure_months  total_charges  num_services  \
# 116   CUST100705            81.32             11        1028.27             6
# 3226  CUST100705            81.32             11        1028.27             6
#
#      internet_service contract_type
# 116       Fiber optic      Two year
# 3226      Fiber optic      Two year

# %%
df = df.drop_duplicates(subset='customer_id',keep='first')

# %%
df.shape
# Out:
# (4987, 17)

# %%
df['customer_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# customer_id             0
# age                    60
# gender                 49
# signup_date             0
# contract_type           0
# internet_service        0
# payment_method         90
# tenure_months           0
# monthly_charges        60
# total_charges           5
# num_services            0
# support_tickets         0
# late_payments           0
# satisfaction_score    100
# last_login_days        75
# city                   50
# churn                   0
# dtype: int64

# %%
df.shape[0]
# Out:
# 4987

# %%
missing_percentage = (df.isnull().sum() / df.shape[0]) * 100

missing_percentage
# Out:
# customer_id           0.000000
# age                   1.203128
# gender                0.982555
# signup_date           0.000000
# contract_type         0.000000
# internet_service      0.000000
# payment_method        1.804692
# tenure_months         0.000000
# monthly_charges       1.203128
# total_charges         0.100261
# num_services          0.000000
# support_tickets       0.000000
# late_payments         0.000000
# satisfaction_score    2.005214
# last_login_days       1.503910
# city                  1.002607
# churn                 0.000000
# dtype: float64

# %%
df['age'].describe()
# Out:
# count    4927.000000
# mean       38.071240
# std        11.650165
# min         9.000000
# 25%        30.000000
# 50%        38.000000
# 75%        46.000000
# max       120.000000
# Name: age, dtype: float64

# %%
df['age'].mean(), df['age'].median()
# Out:
# (np.float64(38.071240105540895), np.float64(38.0))

# %%
df['age'] = df['age'].fillna(df['age'].median())

# %%
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['age'].describe()
# Out:
# count    4987.000000
# mean       38.070383
# std        11.579858
# min         9.000000
# 25%        30.000000
# 50%        38.000000
# 75%        45.500000
# max       120.000000
# Name: age, dtype: float64

# %%
df['gender'].value_counts(dropna=False)
# Out:
# gender
# Male        2460
# Female      2399
# NaN           49
# MALE          40
#  female       39
# Name: count, dtype: int64

# %%
df['gender'].str.lower()
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4         male
#          ...
# 5020    female
# 5021      male
# 5022    female
# 5023      male
# 5024    female
# Name: gender, Length: 4987, dtype: str

# %%
df['gender'] = df['gender'].str.lower()

# %%
df['gender'].value_counts(dropna=False)
# Out:
# gender
# male        2500
# female      2399
# NaN           49
#  female       39
# Name: count, dtype: int64

# %%
df['gender'] = df['gender'].fillna(df['gender'].mode()[0])

# %%
df['gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['age'].describe()
# Out:
# count    4987.000000
# mean       38.070383
# std        11.579858
# min         9.000000
# 25%        30.000000
# 50%        38.000000
# 75%        45.500000
# max       120.000000
# Name: age, dtype: float64

# %%
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['payment_method'].isnull().sum()
# Out:
# np.int64(90)

# %%
df['payment_method'].value_counts(dropna=False)
# Out:
# payment_method
# Electronic check      1730
# Credit card           1419
# Bank transfer         1105
# Mailed check           603
# NaN                     90
#  electronic check       40
# Name: count, dtype: int64

# %%
df['payment_method'] = df['payment_method'].str.lower()

# %%
df['payment_method'].value_counts(dropna=False)
# Out:
# payment_method
# electronic check      1730
# credit card           1419
# bank transfer         1105
# mailed check           603
# NaN                     90
#  electronic check       40
# Name: count, dtype: int64

# %%
df['payment_method']= df['payment_method'].fillna(df['payment_method'].mode()[0])

# %%
df['payment_method'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['monthly_charges'].describe()
# Out:
# count    4927.000000
# mean       60.101419
# std        18.376425
# min        18.000000
# 25%        46.870000
# 50%        59.660000
# 75%        72.395000
# max       121.240000
# Name: monthly_charges, dtype: float64

# %%
df['monthly_charges'].isnull().sum()
# Out:
# np.int64(60)

# %%
df['monthly_charges'].mean(), df['monthly_charges'].median()
# Out:
# (np.float64(60.10141871321291), np.float64(59.66))

# %%
df['monthly_charges'] = df['monthly_charges'].fillna(df['monthly_charges'].median())

# %%
df['monthly_charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['last_login_days'].describe()
# Out:
# count    4912.000000
# mean       18.574919
# std        11.465142
# min         0.000000
# 25%        10.000000
# 50%        16.000000
# 75%        24.000000
# max        90.000000
# Name: last_login_days, dtype: float64

# %%
df['last_login_days'].isnull().sum()
# Out:
# np.int64(75)

# %%
df['last_login_days'].mean(),df['last_login_days'].median()
# Out:
# (np.float64(18.574918566775246), np.float64(16.0))

# %%
df['last_login_days']= df['last_login_days'].fillna(df['last_login_days'].median())

# %%
df['last_login_days'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['city'].isnull().sum()
# Out:
# np.int64(50)

# %%
df['city'].value_counts(dropna=False)
# Out:
# city
# Chennai      896
# Mumbai       829
# Hyderabad    819
# Pune         803
# Bengaluru    803
# Delhi        787
# NaN           50
# Name: count, dtype: int64

# %%
df['city']=df['city'].fillna(df['city'].mode()[0])

# %%
df['city'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['satisfaction_score'].isnull().sum()
# Out:
# np.int64(100)

# %%
df['satisfaction_score'].describe()
# Out:
# count    4887.000000
# mean        6.788418
# std         1.431133
# min         2.000000
# 25%         6.000000
# 50%         7.000000
# 75%         8.000000
# max        10.000000
# Name: satisfaction_score, dtype: float64

# %%
df['satisfaction_score'].mean(),df['satisfaction_score'].median()
# Out:
# (np.float64(6.78841825250665), np.float64(7.0))

# %%
df['satisfaction_score']=df['satisfaction_score'].fillna(df['satisfaction_score'].median())

# %%
df['satisfaction_score'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#       customer_id    age  gender  signup_date  contract_type  \
# 0           False  False   False        False          False
# 1           False  False   False        False          False
# 2           False  False   False        False          False
# 3           False  False   False        False          False
# 4           False  False   False        False          False
# ...           ...    ...     ...          ...            ...
# 5020        False  False   False        False          False
# 5021        False  False   False        False          False
# 5022        False  False   False        False          False
# 5023        False  False   False        False          False
# 5024        False  False   False        False          False
#
#       internet_service  payment_method  tenure_months  monthly_charges  \
# 0                False           False          False            False
# 1                False           False          False            False
# ...

# %%
df.isnull().sum()
# Out:
# customer_id           0
# age                   0
# gender                0
# signup_date           0
# contract_type         0
# internet_service      0
# payment_method        0
# tenure_months         0
# monthly_charges       0
# total_charges         5
# num_services          0
# support_tickets       0
# late_payments         0
# satisfaction_score    0
# last_login_days       0
# city                  0
# churn                 0
# dtype: int64

# %%
df[df['total_charges'].isnull()]
# Out:
#      customer_id   age gender signup_date   contract_type internet_service  \
# 329   CUST104348  43.0   male  2023-01-11  Month-to-month      Fiber optic
# 536   CUST103022  43.0   male  2022-01-15  Month-to-month              DSL
# 1795  CUST100006  40.0   male  2022-11-11  Month-to-month      No internet
# 2223  CUST104198  18.0   male  2022-12-02        One year      No internet
# 3393  CUST101980  40.0   male  2024-08-19        Two year      No internet
#
#         payment_method  tenure_months  monthly_charges  total_charges  \
# 329        credit card             36            59.74            NaN
# 536        credit card             48            50.88            NaN
# 1795       credit card             38            80.19            NaN
# 2223       credit card             37            40.21            NaN
# 3393  electronic check             16            77.55            NaN
#
#       num_services  support_tickets  late_payments  satisfaction_score  \
# ...

# %%
df['total_charges'].isnull().sum()
# Out:
# np.int64(5)

# %%
df['total_charges'].describe()
# Out:
# count    4982.000000
# mean     1804.211943
# std      1205.407816
# min      -500.000000
# 25%       814.035000
# 50%      1630.855000
# 75%      2566.620000
# max      7005.470000
# Name: total_charges, dtype: float64

# %%
df['total_charges'].mean(),df['total_charges'].median()
# Out:
# (np.float64(1804.2119429947809), np.float64(1630.855))

# %%
df['total_charges'] = df['total_charges'].fillna(df['total_charges'].median())

# %%
df['total_charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# customer_id               str
# age                   float64
# gender                    str
# signup_date               str
# contract_type             str
# internet_service          str
# payment_method            str
# tenure_months           int64
# monthly_charges       float64
# total_charges         float64
# num_services            int64
# support_tickets         int64
# late_payments           int64
# satisfaction_score    float64
# last_login_days       float64
# city                      str
# churn                     str
# dtype: object

# %%
df['signup_date']=pd.to_datetime(df['signup_date'])

# %%
df.dtypes
# Out:
# customer_id                      str
# age                          float64
# gender                           str
# signup_date           datetime64[us]
# contract_type                    str
# internet_service                 str
# payment_method                   str
# tenure_months                  int64
# monthly_charges              float64
# total_charges                float64
# num_services                   int64
# support_tickets                int64
# late_payments                  int64
# satisfaction_score           float64
# last_login_days              float64
# city                             str
# churn                            str
# dtype: object

# %%
df.select_dtypes(include='object').nunique()
# Out:
# customer_id         4987
# gender                 3
# contract_type          3
# internet_service       3
# payment_method         5
# city                   6
# churn                  2
# dtype: int64

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['female', 'male', ' female ']
# Length: 3, dtype: str

# %%
df['payment_method'].unique()
# Out:
# <StringArray>
# [       'credit card',      'bank transfer',   'electronic check',
#        'mailed check', ' electronic check ']
# Length: 5, dtype: str

# %%
df['gender']=df['gender'].str.strip()
df['payment_method']=df['payment_method'].str.strip()

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['female', 'male']
# Length: 2, dtype: str

# %%
df['payment_method'].unique()
# Out:
# <StringArray>
# ['credit card', 'bank transfer', 'electronic check', 'mailed check']
# Length: 4, dtype: str

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# electronic check    1860
# credit card         1419
# bank transfer       1105
# mailed check         603
# Name: count, dtype: int64

# %%
df.select_dtypes(include='object').nunique()
# Out:
# customer_id         4987
# gender                 2
# contract_type          3
# internet_service       3
# payment_method         4
# city                   6
# churn                  2
# dtype: int64

# %%
df[df['total_charges'] < 0]
# Out:
#      customer_id   age  gender signup_date   contract_type internet_service  \
# 1029  CUST104203  63.0    male  2024-06-30  Month-to-month      Fiber optic
# 2174  CUST101395  60.0  female  2022-04-23  Month-to-month              DSL
# 2315  CUST101641  44.0  female  2025-07-31  Month-to-month              DSL
# 2621  CUST101791  38.0  female  2023-07-20  Month-to-month      Fiber optic
# 4578  CUST100675  42.0  female  2022-12-14  Month-to-month      Fiber optic
#
#      payment_method  tenure_months  monthly_charges  total_charges  \
# 1029    credit card             18            74.82         -500.0
# 2174  bank transfer             44            27.48         -500.0
# 2315    credit card              5            55.24         -500.0
# 2621  bank transfer             29            95.22         -500.0
# 4578    credit card             37            89.45         -500.0
#
#       num_services  support_tickets  late_payments  satisfaction_score  \
# ...

# %%
(df['total_charges'] < 0).sum()
# Out:
# np.int64(5)

# %%
df['total_charges']=df['total_charges'].replace(-500,np.nan)

# %%
df['total_charges']=df['total_charges'].fillna(df['total_charges'].median())

# %%
df['total_charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
(df['total_charges'] < 0).sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                age                 signup_date  tenure_months  \
# count  4987.000000                        4987     4987.00000
# mean     38.070383  2023-06-26 03:54:10.611590       30.21937
# min       9.000000         2021-01-01 00:00:00        1.00000
# 25%      30.000000         2022-03-29 00:00:00       15.00000
# 50%      38.000000         2023-07-01 00:00:00       30.00000
# 75%      45.500000         2024-09-21 12:00:00       45.00000
# max     120.000000         2025-12-05 00:00:00       60.00000
# std      11.579858                         NaN       17.00565
#
#        monthly_charges  total_charges  num_services  support_tickets  \
# count      4987.000000    4987.000000   4987.000000      4987.000000
# mean         60.096108    1806.174772      3.996591         1.709645
# min          18.000000      17.820000      1.000000         0.000000
# 25%          47.065000     818.550000      3.000000         1.000000
# ...

# %%
df[df['age'] < 18]
# Out:
#      customer_id  age  gender signup_date   contract_type internet_service  \
# 833   CUST104163  9.0    male  2024-02-05  Month-to-month              DSL
# 3348  CUST102548  9.0  female  2023-08-02        One year      Fiber optic
# 3855  CUST101333  9.0  female  2021-09-04        Two year              DSL
#
#         payment_method  tenure_months  monthly_charges  total_charges  \
# 833        credit card             23            88.13        2020.58
# 3348  electronic check             29            55.98        1579.11
# 3855       credit card             52            42.70        2081.50
#
#       num_services  support_tickets  late_payments  satisfaction_score  \
# 833              8                2              2                 7.0
# 3348             3                0              2                 6.0
# 3855             3                1              0                 6.0
#
#       last_login_days       city churn
# 833              18.0     Mumbai    No
# ...

# %%
df[df['age'] > 100]
# Out:
#      customer_id    age  gender signup_date   contract_type internet_service  \
# 212   CUST102042  120.0  female  2022-09-28  Month-to-month      Fiber optic
# 1331  CUST100622  120.0  female  2024-02-02  Month-to-month      Fiber optic
#
#         payment_method  tenure_months  monthly_charges  total_charges  \
# 212   electronic check             39            75.10        2706.40
# 1331     bank transfer             23            86.07        2270.61
#
#       num_services  support_tickets  late_payments  satisfaction_score  \
# 212              6                2              4                 8.0
# 1331             5                3              1                 5.0
#
#       last_login_days     city churn
# 212              18.0  Chennai    No
# 1331             24.0  Chennai    No

# %%
df[df['age'] == 9]
# Out:
#      customer_id  age  gender signup_date   contract_type internet_service  \
# 833   CUST104163  9.0    male  2024-02-05  Month-to-month              DSL
# 3348  CUST102548  9.0  female  2023-08-02        One year      Fiber optic
# 3855  CUST101333  9.0  female  2021-09-04        Two year              DSL
#
#         payment_method  tenure_months  monthly_charges  total_charges  \
# 833        credit card             23            88.13        2020.58
# 3348  electronic check             29            55.98        1579.11
# 3855       credit card             52            42.70        2081.50
#
#       num_services  support_tickets  late_payments  satisfaction_score  \
# 833              8                2              2                 7.0
# 3348             3                0              2                 6.0
# 3855             3                1              0                 6.0
#
#       last_login_days       city churn
# 833              18.0     Mumbai    No
# ...

# %%
df[df['age'] == 9]
# Out:
#      customer_id  age  gender signup_date   contract_type internet_service  \
# 833   CUST104163  9.0    male  2024-02-05  Month-to-month              DSL
# 3348  CUST102548  9.0  female  2023-08-02        One year      Fiber optic
# 3855  CUST101333  9.0  female  2021-09-04        Two year              DSL
#
#         payment_method  tenure_months  monthly_charges  total_charges  \
# 833        credit card             23            88.13        2020.58
# 3348  electronic check             29            55.98        1579.11
# 3855       credit card             52            42.70        2081.50
#
#       num_services  support_tickets  late_payments  satisfaction_score  \
# 833              8                2              2                 7.0
# 3348             3                0              2                 6.0
# 3855             3                1              0                 6.0
#
#       last_login_days       city churn
# 833              18.0     Mumbai    No
# ...

# %%
df['age'].sort_values().head(20)
# Out:
# 3855     9.0
# 833      9.0
# 3348     9.0
# 815     18.0
# 3498    18.0
# 2727    18.0
# 1553    18.0
# 2723    18.0
# 2718    18.0
# 1562    18.0
# 2710    18.0
# 3511    18.0
# 1031    18.0
# 287     18.0
# 2700    18.0
# 2698    18.0
# 2692    18.0
# 2680    18.0
# 4022    18.0
# 3529    18.0
# Name: age, dtype: float64

# %%
df[df['age'] == 9].T
# Out:
#                                    833                  3348  \
# customer_id                  CUST104163           CUST102548
# age                                 9.0                  9.0
# gender                             male               female
# signup_date         2024-02-05 00:00:00  2023-08-02 00:00:00
# contract_type            Month-to-month             One year
# internet_service                    DSL          Fiber optic
# payment_method              credit card     electronic check
# tenure_months                        23                   29
# monthly_charges                   88.13                55.98
# total_charges                   2020.58              1579.11
# num_services                          8                    3
# support_tickets                       2                    0
# late_payments                         2                    2
# satisfaction_score                  7.0                  6.0
# ...

# %%
df['age'].median()
# Out:
# np.float64(38.0)

# %%
df['age'].mean()
# Out:
# np.float64(38.07038299578905)

# %%
df['age'].describe()
# Out:
# count    4987.000000
# mean       38.070383
# std        11.579858
# min         9.000000
# 25%        30.000000
# 50%        38.000000
# 75%        45.500000
# max       120.000000
# Name: age, dtype: float64

# %%
df.loc[df['age'] == 9,'age'] = df['age'].median()

# %%
df[df['age'] == 9]
# Out:
# Empty DataFrame
# Columns: [customer_id, age, gender, signup_date, contract_type, internet_service, payment_method, tenure_months, monthly_charges, total_charges, num_services, support_tickets, late_payments, satisfaction_score, last_login_days, city, churn]
# Index: []

# %%
df['age'].min()
# Out:
# np.float64(18.0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['contract_type'].unique()
# Out:
# <StringArray>
# ['Month-to-month', 'One year', 'Two year']
# Length: 3, dtype: str

# %%
df['contract_type'].value_counts()
# Out:
# contract_type
# Month-to-month    2699
# One year          1433
# Two year           855
# Name: count, dtype: int64

# %%
df['internet_service'].unique()
# Out:
# <StringArray>
# ['No internet', 'DSL', 'Fiber optic']
# Length: 3, dtype: str

# %%
df['city'].unique()
# Out:
# <StringArray>
# ['Chennai', 'Pune', 'Mumbai', 'Bengaluru', 'Delhi', 'Hyderabad']
# Length: 6, dtype: str

# %%
df['expected_total_charges'] = df['monthly_charges'] * df['tenure_months']

# %%
df[['monthly_charges', 'tenure_months', 'total_charges', 'expected_total_charges']].head(10)
# Out:
#    monthly_charges  tenure_months  total_charges  expected_total_charges
# 0            67.42             10         717.36                  674.20
# 1            44.08              4         166.14                  176.32
# 2            32.90             52        1772.94                 1710.80
# 3            59.66             39        2136.76                 2326.74
# 4            58.23              3         193.64                  174.69
# 5            46.98             27        1198.45                 1268.46
# 6            60.26             17        1040.03                 1024.42
# 7            60.59             46        2837.41                 2787.14
# 8            74.28             11         812.64                  817.08
# 9            95.69             19        1936.62                 1818.11

# %%
df['charge_difference'] = (
    df['total_charges'] - df['expected_total_charges']
)

df['charge_difference'].describe()
# Out:
# count    4987.000000
# mean       -1.543943
# std       185.342316
# min     -1678.567500
# 25%       -74.940000
# 50%        -0.440000
# 75%        73.635000
# max      1354.882500
# Name: charge_difference, dtype: float64

# %%
df[['total_charges', 'expected_total_charges', 'charge_difference']].head(10)
# Out:
#    total_charges  expected_total_charges  charge_difference
# 0         717.36                  674.20              43.16
# 1         166.14                  176.32             -10.18
# 2        1772.94                 1710.80              62.14
# 3        2136.76                 2326.74            -189.98
# 4         193.64                  174.69              18.95
# 5        1198.45                 1268.46             -70.01
# 6        1040.03                 1024.42              15.61
# 7        2837.41                 2787.14              50.27
# 8         812.64                  817.08              -4.44
# 9        1936.62                 1818.11             118.51

# %%
df[['monthly_charges',
    'tenure_months',
    'total_charges',
    'expected_total_charges',
    'charge_difference']].sort_values(
        by='charge_difference'
).head(10)
# Out:
#       monthly_charges  tenure_months  total_charges  expected_total_charges  \
# 4578            89.45             37      1631.0825                 3309.65
# 3649            59.66             44      1183.6900                 2625.04
# 1795            80.19             38      1630.8550                 3047.22
# 1255            80.51             51      2962.9500                 4106.01
# 2621            95.22             29      1631.0825                 2761.38
# 1543            81.91             41      2424.9100                 3358.31
# 80              91.29             59      4483.8900                 5386.11
# 1261            59.66             31       983.0800                 1849.46
# 141             83.19             52      3487.0900                 4325.88
# 536             50.88             48      1630.8550                 2442.24
#
#       charge_difference
# 4578         -1678.5675
# 3649         -1441.3500
# 1795         -1416.3650
# 1255         -1143.0600
# ...

# %%
df[['monthly_charges',
    'tenure_months',
    'total_charges',
    'expected_total_charges',
    'charge_difference']].sort_values(
        by='charge_difference',
        ascending=False
).head(10)
# Out:
#       monthly_charges  tenure_months  total_charges  expected_total_charges  \
# 2315            55.24              5      1631.0825                  276.20
# 595             72.25             59      5382.7200                 4262.75
# 2658           103.17             55      6784.6000                 5674.35
# 2921            59.66             27      2642.8200                 1610.82
# 1227            59.66             49      3926.1300                 2923.34
# 705             59.66             52      4074.6300                 3102.32
# 4142            81.75             55      5349.9500                 4496.25
# 984             85.01             60      5954.1100                 5100.60
# 723             88.87             59      6041.9800                 5243.33
# 2637            98.89             55      6210.1400                 5438.95
#
#       charge_difference
# 2315          1354.8825
# 595           1119.9700
# 2658          1110.2500
# 2921          1032.0000
# ...

# %%
df.loc[[4578, 3649, 2315, 595, 2658]]
# Out:
#      customer_id   age  gender signup_date   contract_type internet_service  \
# 4578  CUST100675  42.0  female  2022-12-14  Month-to-month      Fiber optic
# 3649  CUST103390  25.0  female  2022-04-26  Month-to-month      No internet
# 2315  CUST101641  44.0  female  2025-07-31  Month-to-month              DSL
# 595   CUST100683  32.0    male  2021-01-30        One year              DSL
# 2658  CUST102044  21.0    male  2021-06-12  Month-to-month      Fiber optic
#
#         payment_method  tenure_months  monthly_charges  total_charges  \
# 4578       credit card             37            89.45      1631.0825
# 3649  electronic check             44            59.66      1183.6900
# 2315       credit card              5            55.24      1631.0825
# 595   electronic check             59            72.25      5382.7200
# 2658  electronic check             55           103.17      6784.6000
#
#       num_services  support_tickets  late_payments  satisfaction_score  \
# ...

# %%
df.drop(
    columns=['expected_total_charges', 'charge_difference'],
    inplace=True
)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'signup_date', 'contract_type',
#        'internet_service', 'payment_method', 'tenure_months',
#        'monthly_charges', 'total_charges', 'num_services', 'support_tickets',
#        'late_payments', 'satisfaction_score', 'last_login_days', 'city',
#        'churn'],
#       dtype='str')

# %%
df.select_dtypes(include='number').describe().T
# Out:
#                      count         mean          std    min      25%  \
# age                 4987.0    38.087828    11.557869  18.00   30.000
# tenure_months       4987.0    30.219370    17.005650   1.00   15.000
# monthly_charges     4987.0    60.096108    18.265585  18.00   47.065
# total_charges       4987.0  1806.174772  1202.615049  17.82  818.550
# num_services        4987.0     3.996591     1.683367   1.00    3.000
# support_tickets     4987.0     1.709645     1.297160   0.00    1.000
# late_payments       4987.0     1.208743     1.096406   0.00    0.000
# satisfaction_score  4987.0     6.792661     1.417020   2.00    6.000
# last_login_days     4987.0    18.536194    11.382901   0.00   10.000
#
#                           50%      75%      max
# age                   38.0000    45.50   120.00
# tenure_months         30.0000    45.00    60.00
# monthly_charges       59.6600    72.10   121.24
# total_charges       1631.0825  2565.53  7005.47
# ...

# %% [markdown]
# #Personr

# %%
df['churn_binary']= df['churn'].map({
    'No':0,
    'Yes':1
})

# %%
df[['churn','churn_binary']].head(10)
# Out:
#   churn  churn_binary
# 0   Yes             1
# 1    No             0
# 2    No             0
# 3    No             0
# 4    No             0
# 5    No             0
# 6    No             0
# 7    No             0
# 8   Yes             1
# 9    No             0

# %%
from scipy.stats import pearsonr

# %%
numeric_features = [
    'age',
    'tenure_months',
    'monthly_charges',
    'total_charges',
    'num_services',
    'support_tickets',
    'late_payments',
    'satisfaction_score',
    'last_login_days'
]

# %%
correlations = {}

# %%
for col in numeric_features:
    r, p_value = pearsonr(df[col], df['churn_binary'])
    correlations[col] = {
        'correlation': r,
        'p_value': p_value
    }

# %%
correlation_df = pd.DataFrame(correlations).T

# %%
correlation_df
# Out:
#                     correlation       p_value
# age                   -0.025691  6.966134e-02
# tenure_months         -0.137296  2.048031e-22
# monthly_charges        0.042143  2.913914e-03
# total_charges         -0.101442  6.950282e-13
# num_services           0.053480  1.578015e-04
# support_tickets        0.120806  1.124922e-17
# late_payments          0.110059  6.495302e-15
# satisfaction_score    -0.166872  1.807800e-32
# last_login_days        0.134372  1.572583e-21

# %% [markdown]
# #Feature engineering

# %%
df['signup_year'] =df['signup_date'].dt.year

# %%
df[['signup_date','signup_year']].head()
# Out:
#   signup_date  signup_year
# 0  2025-02-26         2025
# 1  2025-08-20         2025
# 2  2021-08-25         2021
# 3  2022-10-09         2022
# 4  2025-09-28         2025

# %%
df['signup_year'].value_counts().sort_index()
# Out:
# signup_year
# 2021     995
# 2022     991
# 2023    1011
# 2024    1057
# 2025     933
# Name: count, dtype: int64

# %%
df.groupby('signup_year')['churn_binary'].mean() * 100
# Out:
# signup_year
# 2021     6.733668
# 2022     8.274470
# 2023    10.880317
# 2024    15.421003
# 2025    19.078242
# Name: churn_binary, dtype: float64

# %%
df['signup_month'] = df['signup_date'].dt.month

# %%
df[['signup_date', 'signup_month']].head()
# Out:
#   signup_date  signup_month
# 0  2025-02-26             2
# 1  2025-08-20             8
# 2  2021-08-25             8
# 3  2022-10-09            10
# 4  2025-09-28             9

# %%
df['signup_month'].value_counts().sort_index()
# Out:
# signup_month
# 1     437
# 2     386
# 3     426
# 4     401
# 5     413
# 6     424
# 7     472
# 8     397
# 9     418
# 10    420
# 11    424
# 12    369
# Name: count, dtype: int64

# %%
df.groupby('signup_month')['churn_binary'].mean() * 100
# Out:
# signup_month
# 1      8.695652
# 2     15.025907
# 3     12.676056
# 4     12.219451
# 5     11.138015
# 6     12.971698
# 7      9.957627
# 8     11.335013
# 9     14.354067
# 10    11.190476
# 11    13.915094
# 12    11.382114
# Name: churn_binary, dtype: float64

# %%
df['avg_monthly_spend'] = df['total_charges'] / df['tenure_months']

# %%
df[['total_charges', 'tenure_months', 'monthly_charges', 'avg_monthly_spend']].head()
# Out:
#    total_charges  tenure_months  monthly_charges  avg_monthly_spend
# 0         717.36             10            67.42          71.736000
# 1         166.14              4            44.08          41.535000
# 2        1772.94             52            32.90          34.095000
# 3        2136.76             39            59.66          54.788718
# 4         193.64              3            58.23          64.546667

# %%
df['avg_monthly_spend'].describe()
# Out:
# count    4987.000000
# mean       60.089606
# std        19.460135
# min        15.374194
# 25%        46.293113
# 50%        59.166415
# 75%        72.589789
# max       326.216500
# Name: avg_monthly_spend, dtype: float64

# %%
df[['customer_id', 'total_charges', 'tenure_months', 'monthly_charges', 'avg_monthly_spend']].sort_values(
    'avg_monthly_spend',
    ascending=False
).head(10)
# Out:
#      customer_id  total_charges  tenure_months  monthly_charges  \
# 2315  CUST101641      1631.0825              5            55.24
# 1756  CUST100442      1967.7300             15           119.93
# 4904  CUST104636       863.5800              7           110.22
# 2658  CUST102044      6784.6000             55           103.17
# 2512  CUST103213      2319.1400             19           113.17
# 2506  CUST103422       970.4000              8           102.50
# 2777  CUST101766      1565.7800             13           108.17
# 3566  CUST101199      5872.1700             50           120.64
# 1844  CUST104684      1055.2900              9           114.28
# 3705  CUST101804      1519.5500             13           106.91
#
#       avg_monthly_spend
# 2315         326.216500
# 1756         131.182000
# 4904         123.368571
# 2658         123.356364
# 2512         122.060000
# 2506         121.300000
# 2777         120.444615
# 3566         117.443400
# 1844         117.254444
# ...

# %%
df[df['customer_id'] == 'CUST101641'].T
# Out:
#                                    2315
# customer_id                  CUST101641
# age                                44.0
# gender                           female
# signup_date         2025-07-31 00:00:00
# contract_type            Month-to-month
# internet_service                    DSL
# payment_method              credit card
# tenure_months                         5
# monthly_charges                   55.24
# total_charges                 1631.0825
# num_services                          5
# support_tickets                       1
# late_payments                         2
# satisfaction_score                  6.0
# last_login_days                     6.0
# city                          Bengaluru
# churn                                No
# churn_binary                          0
# signup_year                        2025
# signup_month                          7
# avg_monthly_spend              326.2165

# %%
df.drop(columns='avg_monthly_spend', inplace=True)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'signup_date', 'contract_type',
#        'internet_service', 'payment_method', 'tenure_months',
#        'monthly_charges', 'total_charges', 'num_services', 'support_tickets',
#        'late_payments', 'satisfaction_score', 'last_login_days', 'city',
#        'churn', 'churn_binary', 'signup_year', 'signup_month'],
#       dtype='str')

# %%
df['tenure_months'].describe()
# Out:
# count    4987.00000
# mean       30.21937
# std        17.00565
# min         1.00000
# 25%        15.00000
# 50%        30.00000
# 75%        45.00000
# max        60.00000
# Name: tenure_months, dtype: float64

# %%
df['tenure_group'] = pd.qcut(
    df['tenure_months'],
    q=4,
    labels=['Q1','Q2','Q3','Q4']
)

# %%
df[['tenure_months', 'tenure_group']].head()
# Out:
#    tenure_months tenure_group
# 0             10           Q1
# 1              4           Q1
# 2             52           Q4
# 3             39           Q3
# 4              3           Q1

# %%
df.groupby('tenure_group')['churn_binary'].mean() * 100
# Out:
# tenure_group
# Q1    18.203498
# Q2    13.364780
# Q3     9.581320
# Q4     6.748971
# Name: churn_binary, dtype: float64

# %%
df.groupby(['late_payments', 'support_tickets'])['churn_binary'].mean() * 100
# Out:
# late_payments  support_tickets
# 0              0                    4.104478
#                1                    6.315789
#                2                    9.230769
#                3                   11.715481
#                4                   10.000000
#                5                   14.285714
#                6                   16.666667
#                7                    0.000000
#                8                    0.000000
# 1              0                    4.573171
#                1                   10.052910
#                2                   10.067114
#                3                   16.724739
#                4                   18.367347
#                5                   23.333333
#                6                   26.666667
#                7                  100.000000
# 2              0                   10.824742
#                1                   13.245033
#                2                   17.013889
# ...

# %%
df.groupby(['late_payments', 'support_tickets']).size()
# Out:
# late_payments  support_tickets
# 0              0                  268
#                1                  475
#                2                  390
#                3                  239
#                4                   90
#                5                   28
#                6                    6
#                7                    2
#                8                    1
# 1              0                  328
#                1                  567
#                2                  447
#                3                  287
#                4                   98
#                5                   30
#                6                   15
#                7                    3
# 2              0                  194
#                1                  302
#                2                  288
#                3                  192
#                4                   78
#                5                   25
#                6                    6
# ...

# %%
df['warning_signal_count'] = df['late_payments'] + df['support_tickets']

# %%
df[['late_payments', 'support_tickets', 'warning_signal_count']].head()
# Out:
#    late_payments  support_tickets  warning_signal_count
# 0              2                0                     2
# 1              0                0                     0
# 2              0                2                     2
# 3              2                0                     2
# 4              3                1                     4

# %%
df['warning_signal_count'].value_counts().sort_index()
# Out:
# warning_signal_count
# 0      268
# 1      803
# 2     1151
# 3     1069
# 4      823
# 5      498
# 6      230
# 7       98
# 8       33
# 9       11
# 10       2
# 11       1
# Name: count, dtype: int64

# %%
df.groupby('warning_signal_count')['churn_binary'].mean() * 100
# Out:
# warning_signal_count
# 0       4.104478
# 1       5.603985
# 2       9.904431
# 3      11.318990
# 4      16.524909
# 5      16.465863
# 6      20.434783
# 7      31.632653
# 8      24.242424
# 9      27.272727
# 10     50.000000
# 11    100.000000
# Name: churn_binary, dtype: float64

# %%
pearsonr(df['warning_signal_count'], df['churn_binary'])
# Out:
# PearsonRResult(statistic=np.float64(0.16221666070677074), pvalue=np.float64(9.412939368600179e-31))

# %%
df['last_login_days'].describe()
# Out:
# count    4987.000000
# mean       18.536194
# std        11.382901
# min         0.000000
# 25%        10.000000
# 50%        16.000000
# 75%        24.000000
# max        90.000000
# Name: last_login_days, dtype: float64

# %%
df.groupby('last_login_days')['churn_binary'].mean() * 100
# Out:
# last_login_days
# 0.0       0.000000
# 1.0       0.000000
# 2.0       0.000000
# 3.0      10.294118
# 4.0       6.818182
#            ...
# 75.0      0.000000
# 77.0    100.000000
# 78.0    100.000000
# 83.0     50.000000
# 90.0    100.000000
# Name: churn_binary, Length: 78, dtype: float64

# %%
df['inactivity_group'] = pd.cut(
    df['last_login_days'],
    bins=[-1, 7, 14, 30, 60, 90],
    labels=['0-7', '8-14', '15-30', '31-60', '61-90']
)

# %%
df[['last_login_days', 'inactivity_group']].head()
# Out:
#    last_login_days inactivity_group
# 0             43.0            31-60
# 1              2.0              0-7
# 2             22.0            15-30
# 3             18.0            15-30
# 4             35.0            31-60

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'signup_date', 'contract_type',
#        'internet_service', 'payment_method', 'tenure_months',
#        'monthly_charges', 'total_charges', 'num_services', 'support_tickets',
#        'late_payments', 'satisfaction_score', 'last_login_days', 'city',
#        'churn', 'churn_binary', 'signup_year', 'signup_month', 'tenure_group',
#        'warning_signal_count', 'inactivity_group'],
#       dtype='str')

# %%
df[numeric_features].corr()
# Out:
#                          age  tenure_months  monthly_charges  total_charges  \
# age                 1.000000       0.015973        -0.010013       0.009984
# tenure_months       0.015973       1.000000        -0.026880       0.836989
# monthly_charges    -0.010013      -0.026880         1.000000       0.434792
# total_charges       0.009984       0.836989         0.434792       1.000000
# num_services       -0.020251      -0.014554         0.718057       0.316925
# support_tickets     0.012711       0.003570        -0.018859      -0.008134
# late_payments       0.002573       0.016099        -0.014466       0.008505
# satisfaction_score -0.000100       0.028164        -0.005195       0.021775
# last_login_days     0.003006      -0.005665        -0.019642      -0.014903
#
#                     num_services  support_tickets  late_payments  \
# age                    -0.020251         0.012711       0.002573
# tenure_months          -0.014554         0.003570       0.016099
# ...

# %%
df[numeric_features].corr().abs().unstack().sort_values(ascending=False)
# Out:
# age                 age                   1.000000
# tenure_months       tenure_months         1.000000
# satisfaction_score  satisfaction_score    1.000000
# late_payments       late_payments         1.000000
# support_tickets     support_tickets       1.000000
#                                             ...
# age                 late_payments         0.002573
# num_services        satisfaction_score    0.001978
# satisfaction_score  num_services          0.001978
#                     age                   0.000100
# age                 satisfaction_score    0.000100
# Length: 81, dtype: float64

# %%
corr_matrix = df[numeric_features].corr()

# %%
upper_triangle =corr_matrix.where(
    np.triu(np.ones(corr_matrix.shape),k=1).astype(bool)
)

# %%
upper_triangle
# Out:
#                     age  tenure_months  monthly_charges  total_charges  \
# age                 NaN       0.015973        -0.010013       0.009984
# tenure_months       NaN            NaN        -0.026880       0.836989
# monthly_charges     NaN            NaN              NaN       0.434792
# total_charges       NaN            NaN              NaN            NaN
# num_services        NaN            NaN              NaN            NaN
# support_tickets     NaN            NaN              NaN            NaN
# late_payments       NaN            NaN              NaN            NaN
# satisfaction_score  NaN            NaN              NaN            NaN
# last_login_days     NaN            NaN              NaN            NaN
#
#                     num_services  support_tickets  late_payments  \
# age                    -0.020251         0.012711       0.002573
# tenure_months          -0.014554         0.003570       0.016099
# ...

# %%
# FLOW CHART OF THIS PROJECT


# Cleaning
#    ↓
# EDA
#    ↓
# Outlier / invalid-value handling
#    ↓
# Data consistency checks
#    ↓
# Pearson correlation
#    ↓
# Date feature extraction
#    ↓
# Average monthly spend
#    ↓
# Tenure grouping
#    ↓
# Warning-signal feature
#    ↓
# Inactivity grouping
#    ↓
# Correlation / redundancy investigation

# %%
categorical_features = [
    'gender',
    'contract_type',
    'internet_service',
    'payment_method',
    'city',
    'tenure_group',
    'inactivity_group'
]

# %%
df[categorical_features].nunique()
# Out:
# gender              2
# contract_type       3
# internet_service    3
# payment_method      4
# city                6
# tenure_group        4
# inactivity_group    5
# dtype: int64

# %%
one_hot_features = [
    'gender',
    'contract_type',
    'internet_service',
    'payment_method',
    'city'
]

# %%
df_encoded = pd.get_dummies(df,columns=one_hot_features,drop_first=True,dtype=int)

# %%
df_encoded.columns
# Out:
# Index(['customer_id', 'age', 'signup_date', 'tenure_months', 'monthly_charges',
#        'total_charges', 'num_services', 'support_tickets', 'late_payments',
#        'satisfaction_score', 'last_login_days', 'churn', 'churn_binary',
#        'signup_year', 'signup_month', 'tenure_group', 'warning_signal_count',
#        'inactivity_group', 'gender_male', 'contract_type_One year',
#        'contract_type_Two year', 'internet_service_Fiber optic',
#        'internet_service_No internet', 'payment_method_credit card',
#        'payment_method_electronic check', 'payment_method_mailed check',
#        'city_Chennai', 'city_Delhi', 'city_Hyderabad', 'city_Mumbai',
#        'city_Pune'],
#       dtype='str')

# %%
df_encoded[['tenure_group', 'inactivity_group']].head()
# Out:
#   tenure_group inactivity_group
# 0           Q1            31-60
# 1           Q1              0-7
# 2           Q4            15-30
# 3           Q3            15-30
# 4           Q1            31-60

# %%
tenure_mapping={
    'Q1' :1,
    'Q2' :2,
    'Q3' :3,
    'Q4' :4
}

df_encoded['tenure_group_encoded'] = df_encoded['tenure_group'].map(tenure_mapping)

# %%
df_encoded[['tenure_group', 'tenure_group_encoded']].head()
# Out:
#   tenure_group tenure_group_encoded
# 0           Q1                    1
# 1           Q1                    1
# 2           Q4                    4
# 3           Q3                    3
# 4           Q1                    1

# %%
inactivity_mapping = {
    '0-7': 1,
    '8-14': 2,
    '15-30': 3,
    '31-60': 4,
    '61-90': 5
}

df_encoded['inactivity_group_encoded'] = (
    df_encoded['inactivity_group'].map(inactivity_mapping)
)

# %%
df_encoded[['inactivity_group', 'inactivity_group_encoded']].head()
# Out:
#   inactivity_group inactivity_group_encoded
# 0            31-60                        4
# 1              0-7                        1
# 2            15-30                        3
# 3            15-30                        3
# 4            31-60                        4

# %%
df_encoded.dtypes
# Out:
# customer_id                                   str
# age                                       float64
# signup_date                        datetime64[us]
# tenure_months                               int64
# monthly_charges                           float64
# total_charges                             float64
# num_services                                int64
# support_tickets                             int64
# late_payments                               int64
# satisfaction_score                        float64
# last_login_days                           float64
# churn                                         str
# churn_binary                                int64
# signup_year                                 int32
# signup_month                                int32
# tenure_group                             category
# warning_signal_count                        int64
# inactivity_group                         category
# gender_male                                 int64
# ...

# %%
df_encoded['tenure_group_encoded'] = df_encoded['tenure_group_encoded'].astype(int)

# %%
df_encoded['inactivity_group_encoded'] = df_encoded['inactivity_group_encoded'].astype(int)

# %%
df_encoded[['tenure_group_encoded', 'inactivity_group_encoded']].dtypes
# Out:
# tenure_group_encoded        int64
# inactivity_group_encoded    int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X= df_encoded.drop(['churn','churn_binary','customer_id','signup_date','tenure_group','inactivity_group'],axis=1)
Y= df_encoded['churn_binary']

# %%
X.shape,Y.shape
# Out:
# ((4987, 27), (4987,))

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.20,random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3989, 27), (998, 27), (3989,), (998,))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred[:10]
# Out:
# array([ 0.05378598,  0.1025458 , -0.06926326,  0.1383529 ,  0.1451289 ,
#         0.03072105,  0.08034255,  0.04649976, -0.00654109,  0.09843607])

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.05517618449035255

# %%
n = X_test.shape[0]
p = X_test.shape[1]

adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))

adjusted_r2
# Out:
# 0.028876964883382983

# %%
df_encoded.columns
# Out:
# Index(['customer_id', 'age', 'signup_date', 'tenure_months', 'monthly_charges',
#        'total_charges', 'num_services', 'support_tickets', 'late_payments',
#        'satisfaction_score', 'last_login_days', 'churn', 'churn_binary',
#        'signup_year', 'signup_month', 'tenure_group', 'warning_signal_count',
#        'inactivity_group', 'gender_male', 'contract_type_One year',
#        'contract_type_Two year', 'internet_service_Fiber optic',
#        'internet_service_No internet', 'payment_method_credit card',
#        'payment_method_electronic check', 'payment_method_mailed check',
#        'city_Chennai', 'city_Delhi', 'city_Hyderabad', 'city_Mumbai',
#        'city_Pune', 'tenure_group_encoded', 'inactivity_group_encoded'],
#       dtype='str')

# %%
df_encoded['monthly_charge_per_service']=df_encoded['monthly_charges'] / df_encoded['num_services']

# %%
df_encoded['monthly_charge_per_service']
# Out:
# 0       16.855000
# 1       11.020000
# 2       10.966667
# 3       59.660000
# 4       14.557500
#           ...
# 5020    15.966667
# 5021    16.556667
# 5022    12.710000
# 5023    23.483333
# 5024    19.020000
# Name: monthly_charge_per_service, Length: 4987, dtype: float64

# %%
X = df_encoded.drop(
    ['churn', 'churn_binary', 'customer_id',
     'signup_date', 'tenure_group', 'inactivity_group'],
    axis=1
)
Y = df_encoded['churn_binary']

X.shape, Y.shape
# Out:
# ((4987, 28), (4987,))

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.20,random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3989, 28), (998, 28), (3989,), (998,))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.05385379561875714

# %%
n=X_test.shape[0]
p=X_test.shape[1]

adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
adjusted_r2
# Out:
# 0.026514173613932823

# %%
df_encoded = df_encoded.drop('monthly_charge_per_service', axis=1)

# %%
df_encoded.shape
# Out:
# (4987, 33)

# %%
df_encoded['customer_risk_score'] = (
    df_encoded['support_tickets']
    + df_encoded['late_payments']
    + df_encoded['last_login_days']
)

# %%
X = df_encoded.drop(
    ['churn', 'churn_binary', 'customer_id',
     'signup_date', 'tenure_group', 'inactivity_group'],
    axis=1
)

Y= df_encoded['churn_binary']

X.shape, Y.shape
# Out:
# ((4987, 28), (4987,))

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.20,random_state=42)

X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((3989, 28), (998, 28), (3989,), (998,))

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.05517618449034645

# %%
n=X_test.shape[0]
p=X_test.shape[1]


adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
adjusted_r2
# Out:
# 0.027874773928664
